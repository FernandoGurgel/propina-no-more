# %%
import pandas as pd
import numpy as np
data = 'https://raw.githubusercontent.com/FernandoGurgel/propina-no-more/master/bases/export_transparencia_2018.csv'
dataset = pd.read_csv(data, sep=";")
print("Extração concluída")



# import json
# with open('dadosOrgaos2018.json', 'w', encoding='utf-8') as file:
#     teste.to_json(file, force_ascii=False)
    
# print("Arquivo de 2018 salvo com sucesso!")
# Out:
# Extração concluída

# %%
unidades = dataset['UG_Sigla']
teste = dataset.groupby(['UG_Sigla','UG_Nome'])['UG_Sigla','UG_Nome']

# %%
t = dict(teste.count()['UG_Sigla'])
t
# Out:
# {('AADC', 'AGÊNCIA AMAZONENSE DE DESENVOLVIMENTO CULTURAL'): 6,
#  ('AADES', 'AGÊNCIA AMAZONENSE DE DESENVOLVIMENTO ECONÔMICO E SOCIAL'): 129,
#  ('ADAF',
#   'AGÊNCIA DE DEFESA AGROPECUÁRIA E FLORESTAL DO ESTADO DO AMAZONAS'): 108,
#  ('ADFEAM', 'AGÊNCIA DE DESENVOLVIMENTO E FOMENTO DO ESTADO DO AMAZONAS'): 24,
#  ('AMAZONASTUR', 'EMPRESA ESTADUAL DE TURISMO DO AMAZONAS'): 16,
#  ('AMAZONPREV', 'FUNDAÇÃO FUNDO PREVIDENCIÁRIO DO ESTADO DO AMAZONAS'): 302,
#  ('ARSAM',
#   'AGÊNCIA REGULADORA DOS SERVIÇOS PÚBLICOS CONCEDIDOS DO ESTADO DO AMAZONAS'): 158,
#  ('CASA CIVIL', 'SECRETARIA DE ESTADO DA CASA CIVIL'): 193,
#  ('CASA MILITAR', 'SECRETARIA DE ESTADO DA CASA MILITAR'): 130,
#  ('CBMAM', 'CORPO DE BOMBEIROS MILITAR DO AMAZONAS'): 323,
#  ('CEMA',
#   'CENTRAL DE MEDICAMENTOS DA SECRETARIA DE ESTADO DA SAÚDE DO AM'): 527,
#  ('CETAM', 'CENTRO DE EDUCAÇÁO TECNOLÓGICA DO AMAZONAS'): 1203,
#  ('CGE', 'CONTROLADORIA GERAL DO ESTADO'): 52,
#  ('CGL', 'COMISSÃO GERAL DE LICITAÇÃO DO PODER EXECUTIVO'): 141,
#  ('CHAPOT PREVOST', 'HOSPITAL DE ISOLAMENTO CHAPOT PREVOST'): 419,
#  ('CPER', 'CENTRO PSIQUIÁTRICO EDUARDO RIBEIRO'): 310,
#  ('DEFESA CIVIL', 'SUBCOMANDO DE AÇÕES DE DEFESA CIVIL'): 137,
#  ('DETRAN-AM', 'DEPARTAMENTO ESTADUAL DE TRÂNSITO'): 658,
#  ('ERGSP', 'ESCRITÓRIO DE REPRESENTAÇÃO DO GOVERNO EM SÃO PAULO'): 4,
#  ('FAPEAM', 'FUNDAÇÃO DE AMPARO À PESQUISA DO ESTADO DO AMAZONAS'): 200,
#  ('FCECON',
#   'FUNDAÇÃO CENTRO DE CONTROLE DE ONCOLOGIA DO ESTADO DO AMAZONAS'): 3206,
#  ('FEAS', 'FUNDO ESTADUAL DE ASSISTÊNCIA SOCIAL'): 602,
#  ('FECA', 'FUNDO ESTADUAL DA CRIANÇA E DO ADOLESCENTE'): 10,
#  ('FEEL', 'FUNDO ESTADUAL DE ESPORTE E LAZER'): 60,
#  ('FEI', 'FUNDAÇÃO ESTADUAL DO ÍNDIO'): 206,
#  ('FERF', 'FUNDO ESTADUAL DE REGULARIZAÇÃO FUNDIÁRIA'): 53,
#  ('FERH', 'FUNDO ESTADUAL DE RECURSOS HÍDRICOS'): 40,
#  ('FES', 'FUNDO ESTADUAL DE SAÚDE'): 14,
#  ('FHAJ', 'FUNDAÇÃO HOSPITAL ADRIANO JORGE'): 2142,
#  ('FHEMOAM', 'FUNDAÇÃO DE HEMATOLOGIA E HEMOTERAPIA DO AMAZONAS'): 2067,
#  ('FMT',
#   'FUNDAÇÃO DE MEDICINA TROPICAL ``DOUTOR HEITOR VIEIRA DOURADO``'): 1512,
#  ('FPEAM', 'FUNDO PENITENCIÁRIO DO ESTADO DO AMAZONAS'): 106,
#  ('FRAI-SSP', 'FUNDO DE RESERVA PARA AÇÕES DE INTELIGÊNCIA'): 143,
#  ('FUAM',
#   'FUNDAÇÃO DE DERMATOLOGIA TROPICAL E VENEREOLOGIA ALFREDO DA MATTA'): 819,
#  ('FUNDECC', 'FUNDO ESTADUAL DE DEFESA DO CONSUMIDOR'): 98,
#  ('FUNDO SEFAZ', 'FUNDO PARA FINANCIAMENTO DA MODERNIZAÇÃO'): 28,
#  ('FUNDPGE',
#   'FUNDO ESPECIAL DA PROCURADORIA GERAL DO ESTADO DO AMAZONAS - FUNDPGE'): 192,
#  ('FUNESBOM', 'FUNDO ESPECIAL DO CORPO DE BOMBEIROS MILITAR DO AMAZONAS'): 131,
#  ('FUNTEC', 'FUNDAÇÃO TELEVISÃO E RÁDIO CULTURA DO AMAZONAS'): 557,
#  ('FVS/AM', 'FUNDAÇÃO DE VIGILÂNCIA EM SAÚDE DO ESTADO DO AMAZONAS'): 2928,
#  ('H. I. Dr Fajardo', 'HOSPITAL INFANTIL DR. FAJARDO'): 376,
#  ('HGGR', 'HOSPITAL GERAL DR. GERALDO DA ROCHA'): 450,
#  ('HPS JLUCIO',
#   'HOSPITAL E PRONTO SOCORRO DR. JOÃO LÚCIO PEREIRA MACHADO'): 1304,
#  ('HPSC  LESTE', 'HOSPITAL E PRONTO SOCORRO DA CRIANÇA - ZONA LESTE'): 1097,
#  ('HPSC OESTE', 'HOSPITAL E PRONTO SOCORRO DA CRIANÇA - ZONA OESTE'): 1424,
#  ('ICAM', 'INSTITUTO DE SAÚDE DA CRIANÇA DO AMAZONAS'): 708,
#  ('IDAM',
#   'INSTITUTO DE DESENVOLVIMENTO AGROPECUÁRIO E FLORESTAL SUSTENTÁVEL DO ESTADO DO AMAZONAS'): 596,
#  ('IM', 'INSTITUTO DA MULHER'): 1294,
#  ('IMPEAM', 'IMPRENSA OFICIAL DO ESTADO DO AMAZONAS'): 1315,
#  ('IPAAM', 'INSTITUTO DE PROTEÇÃO AMBIENTAL DO ESTADO DO AMAZONAS'): 236,
#  ('IPEM', 'INSTITUTO DE PESOS E MEDIDAS'): 4,
#  ('JUCEA', 'JUNTA COMERCIAL DO ESTADO'): 216,
#  ('MAT ANA BRAGA',
#   'MATERNIDADE DE REFERÊNCIA DA ZONA LESTE DE MANAUS - ANA BRAGA'): 555,
#  ('MATERNIDADE ALVORADA', 'MATERNIDADE ALVORADA - CAMI I'): 730,
#  ('MATERNIDADE AZILDA MARREIRO', 'MATERNIDADE AZILDA MARREIRO'): 593,
#  ('MATERNIDADE BALBINA', 'MATERNIDADE BALBINA MESTRINHO'): 467,
#  ('MATERNIDADE NAZIRA DAOU', 'MATERNIDADE DONA NAZIRA DAOU - CAMI II'): 772,
#  ('OUVIDORIA', 'OUVIDORIA GERAL DO ESTADO'): 19,
#  ('PAM CENTRO', 'POLICLÍNICA GOVERNADOR GILBERTO MESTRINHO'): 68,
#  ('PAM CODAJAS', 'POSTO DE ASSISTÊNCIA MÉDICO - PAM CODAJAS'): 608,
#  ('PGE', 'PROCURADORIA GERAL DO ESTADO'): 49,
#  ('PLAALX', 'POLICLÍNICA ANTONIO ALEIXO'): 555,
#  ('POLICLINICA ZENO LANZINI', 'POLICLINICA ZENO LANZINE'): 278,
#  ('POLICLÍNICA DANILO CORREA', 'SPA E POLICLÍNICA DR. DANILO CORRÊA'): 682,
#  ('POLICLÍNICA JOSÉ LINS',
#   'SERVIÇO DE PRONTO ATENDIMENTO E POLICLINICA DR. JOSE DE JESUS LINS'): 574,
#  ('POLICLÍNICA JOÃO BRAGA', 'POLICLINICA JOAO DOS SANTOS BRAGA'): 429,
#  ('POLÍCIA CIVIL', 'POLÍCIA CIVIL DO ESTADO DO AMAZONAS'): 420,
#  ('POLÍCIA MILITAR', 'POLÍCIA MILITAR DO AMAZONAS'): 583,
#  ('PS 28 AGOSTO', 'PRONTO SOCORRO 28 DE AGOSTO'): 722,
#  ('PSC  SUL', 'PRONTO SOCORRO DA CRIANÇA - ZONA SUL'): 1202,
#  ('SEAD', 'SECRETARIA DE ESTADO DE ADMINISTRAÇÃO E GESTÃO'): 199,
#  ('SEAP', 'SECRETARIA DE ESTADO DE ADMINISTRAÇÃO PENITENCIÁRIA'): 214,
#  ('SEAS', 'SECRETARIA DE ESTADO DE ASSISTÊNCIA SOCIAL'): 402,
#  ('SEC', 'SECRETARIA DE ESTADO DE CULTURA'): 185,
#  ('SECOM', 'SECRETARIA DE ESTADO DE COMUNICAÇÃO SOCIAL'): 27,
#  ('SEDUC', 'SECRETARIA DE ESTADO DE EDUCAÇÃO E QUALIDADE DO ENSINO'): 3468,
#  ('SEFAZ', 'SECRETARIA DE ESTADO DA FAZENDA'): 6774,
#  ('SEFAZ  ENCARGOS',
#   'SECRETARIA DE ESTADO DA FAZENDA - SEFAZ - ENCARGOS GERAIS DO ESTADO'): 6,
#  ('SEINF', 'SECRETARIA DE ESTADO DE INFRA-ESTRUTURA'): 349,
#  ('SEJEL', 'SECRETARIA DE ESTADO DA JUVENTUDE, ESPORTE E LAZER'): 264,
#  ('SEJUSC',
#   'SECRETARIA DE ESTADO DE JUSTIÇA , DIREITOS HUMANOS E CIDADANIA'): 194,
#  ('SEMA', 'SECRETARIA DE ESTADO DO MEIO AMBIENTE'): 258,
#  ('SEPED', 'SECRETARIA DE ESTADO DOS DIREITOS DA PESSOA COM DEFICIÊNCIA'): 25,
#  ('SEPLANCTI',
#   'SECRETARIA DE ESTADO DE PLANEJAMENTO, DESENVOLVIMENTO, CIÊNCIA, TECNOLOGIA E INOVAÇÃO'): 110,
#  ('SEPROR', 'SECRETARIA DE ESTADO DE PRODUÇÃO RURAL'): 396,
#  ('SERINS',
#   'SECRETARIA DE ESTADO DE RELAÇÕES INSTITUCIONAIS E REPRES. DO AMAZONAS'): 33,
#  ('SETRAB', 'SECRETARIA DE ESTADO DO TRABALHO'): 413,
#  ('SNPH', 'SUPERINTENDENCIA  ESTADUAL DE NAVEGAÇÃO PORTOS E HIDROVIAS'): 68,
#  ('SPA ALVORADA', 'SERVIÇO DE PRONTO ATENDIMENTO - ALVORADA'): 907,
#  ('SPA COROADO', 'SERVIÇO DE PRONTO ATENDIMENTO - COROADO'): 631,
#  ('SPA E HOSPITAL DR. PLATÃO',
#   'SPA E HOSPITAL DR. ARISTOTELES PLATÃO BEZERRA DE ARAUJO'): 905,
#  ('SPA ELIAMEME RODRIGUES MADY',
#   'SERVIÇO DE PRONTO ATENDIMENTO ELIAMEME RODRIGUES MADY'): 578,
#  ('SPA JOVENTINA DIAS',
#   'SERVIÇO DE PRONTO ATENDIMENTO - JOVENTINA DIAS'): 1124,
#  ('SPA SÃO RAIMUNDO', 'SERVIÇO DE PRONTO ATENDIMENTO - SÃO RAIMUNDO'): 679,
#  ('SPA ZONA SUL', 'SERVIÇO DE PRONTO ATENDIMENTO - ZONA SUL'): 1775,
#  ('SPF', 'SECRETARIA DE ESTADO DE POLÍTICA FUNDIÁRIA'): 38,
#  ('SRMM',
#   'SECRETARIA DE ESTADO DE DESENVOLVIMENTO DA REGIÃO METROPOLITANA DE MANAUS'): 344,
#  ('SSP', 'SECRETARIA DE ESTADO DE SEGURANÇA PÚBLICA'): 701,
#  ('SUHAB', 'SUPERINTENDÊNCIA ESTADUAL DE HABITAÇÃO - SUHAB'): 380,
#  ('SUSAM', 'SECRETARIA DE ESTADO DE SAÚDE'): 5065,
#  ('UEA', 'UNIVERSIDADE DO ESTADO DO AMAZONAS'): 746,
#  ('UGPE', 'UNIDADE GESTORA DE PROJETOS ESPECIAIS'): 71,
#  ('VICE-GOVERNADORIA', 'VICE-GOVERNADORIA  - SECRETARIA EXECUTIVA'): 118}

# %%
dados = []
# d = [{'sigla': 'AAD', 'nome': 'FUNDO'}, {'sigla': 'AAD', 'nome': 'FUNDO'}]
# d
for i in t.keys():
    dados.append({'sigla': i[0], 'nome': i[1]}) 
#     print(i[1])

type(dados)

import json

orgaos = json.dumps(dados)

with open('orgaos.json', 'w', encoding='utf-8') as file:
    dados.to_json(file, force_ascii=False)
    
print("Arquivo de 2018 salvo com sucesso!")
